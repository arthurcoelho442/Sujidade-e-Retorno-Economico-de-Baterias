# %% [markdown]
# # **Inicialização**

# %%
pip install -r requirements.txt
# Out:
# Requirement already satisfied: pandas in c:\users\arthur\documents\github\fontes-renovaveis\.venv\lib\site-packages (from -r requirements.txt (line 1)) (2.3.1)
# Requirement already satisfied: matplotlib in c:\users\arthur\documents\github\fontes-renovaveis\.venv\lib\site-packages (from -r requirements.txt (line 2)) (3.10.5)
# Requirement already satisfied: pymoo in c:\users\arthur\documents\github\fontes-renovaveis\.venv\lib\site-packages (from -r requirements.txt (line 3)) (0.6.1.5)
# Requirement already satisfied: pvlib in c:\users\arthur\documents\github\fontes-renovaveis\.venv\lib\site-packages (from -r requirements.txt (line 4)) (0.13.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\arthur\documents\github\fontes-renovaveis\.venv\lib\site-packages (from pandas->-r requirements.txt (line 1)) (2.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\arthur\documents\github\fontes-renovaveis\.venv\lib\site-packages (from pandas->-r requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\arthur\documents\github\fontes-renovaveis\.venv\lib\site-packages (from pandas->-r requirements.txt (line 1)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\arthur\documents\github\fontes-renovaveis\.venv\lib\site-packages (from pandas->-r requirements.txt (line 1)) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\arthur\documents\github\fontes-renovaveis\.venv\lib\site-packages (from matplotlib->-r requirements.txt (line 2)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\arthur\documents\github\fontes-renovaveis\.venv\lib\site-packages (from matplotlib->-r requirements.txt (line 2)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\arthur\documents\github\fontes-renovaveis\.venv\lib\site-packages (from matplotlib->-r requirements.txt (line 2)) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\arthur\documents\github\fontes-renovaveis\.venv\lib\site-packages (from matplotlib->-r requirements.txt (line 2)) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\arthur\documents\github\fontes-renovaveis\.venv\lib\site-packages (from matplotlib->-r requirements.txt (line 2)) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\arthur\documents\github\fontes-renovaveis\.venv\lib\site-packages (from matplotlib->-r requirements.txt (line 2)) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\arthur\documents\github\fontes-renovaveis\.venv\lib\site-packages (from matplotlib->-r requirements.txt (line 2)) (3.2.3)
# Requirement already satisfied: scipy>=1.1 in c:\users\arthur\documents\github\fontes-renovaveis\.venv\lib\site-packages (from pymoo->-r requirements.txt (line 3)) (1.16.1)
# Requirement already satisfied: autograd>=1.4 in c:\users\arthur\documents\github\fontes-renovaveis\.venv\lib\site-packages (from pymoo->-r requirements.txt (line 3)) (1.8.0)
# Requirement already satisfied: cma>=3.2.2 in c:\users\arthur\documents\github\fontes-renovaveis\.venv\lib\site-packages (from pymoo->-r requirements.txt (line 3)) (4.3.0)
# Requirement already satisfied: alive-progress in c:\users\arthur\documents\github\fontes-renovaveis\.venv\lib\site-packages (from pymoo->-r requirements.txt (line 3)) (3.3.0)
# Requirement already satisfied: dill in c:\users\arthur\documents\github\fontes-renovaveis\.venv\lib\site-packages (from pymoo->-r requirements.txt (line 3)) (0.4.0)
# Requirement already satisfied: Deprecated in c:\users\arthur\documents\github\fontes-renovaveis\.venv\lib\site-packages (from pymoo->-r requirements.txt (line 3)) (1.2.18)
# Requirement already satisfied: requests in c:\users\arthur\documents\github\fontes-renovaveis\.venv\lib\site-packages (from pvlib->-r requirements.txt (line 4)) (2.32.4)
# Requirement already satisfied: h5py in c:\users\arthur\documents\github\fontes-renovaveis\.venv\lib\site-packages (from pvlib->-r requirements.txt (line 4)) (3.14.0)
# Requirement already satisfied: six>=1.5 in c:\users\arthur\documents\github\fontes-renovaveis\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 1)) (1.17.0)
# Requirement already satisfied: about-time==4.2.1 in c:\users\arthur\documents\github\fontes-renovaveis\.venv\lib\site-packages (from alive-progress->pymoo->-r requirements.txt (line 3)) (4.2.1)
# Requirement already satisfied: graphemeu==0.7.2 in c:\users\arthur\documents\github\fontes-renovaveis\.venv\lib\site-packages (from alive-progress->pymoo->-r requirements.txt (line 3)) (0.7.2)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\arthur\documents\github\fontes-renovaveis\.venv\lib\site-packages (from Deprecated->pymoo->-r requirements.txt (line 3)) (1.17.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\arthur\documents\github\fontes-renovaveis\.venv\lib\site-packages (from requests->pvlib->-r requirements.txt (line 4)) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\arthur\documents\github\fontes-renovaveis\.venv\lib\site-packages (from requests->pvlib->-r requirements.txt (line 4)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\arthur\documents\github\fontes-renovaveis\.venv\lib\site-packages (from requests->pvlib->-r requirements.txt (line 4)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\arthur\documents\github\fontes-renovaveis\.venv\lib\site-packages (from requests->pvlib->-r requirements.txt (line 4)) (2025.8.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
#@title **Bibliotecas**

from operator import itemgetter

# Importação do pandas
import pandas as pd

# Importação do numpy
import numpy as np

# Importa MatPlot
import matplotlib.pyplot as plt

import math

import numpy as np

import random

import os

from random import shuffle

from pymoo.problems.functional import FunctionalProblem
from pymoo.algorithms.moo.nsga3 import NSGA3
from pymoo.optimize import minimize
from pymoo.visualization.scatter import Scatter
from pymoo.util.ref_dirs import get_reference_directions

# %%
#@title **Dados de consumo database Bear_education_Danna e Bear_education_Darrell**

dir = "./Genome_Separate_Buildings/"

# Listar todos os arquivos na pasta
all_files = os.listdir(dir)
csv_files = [f for f in all_files if f.endswith('.csv')]

# Embaralhar a lista de arquivos CSV
shuffle(csv_files)

# Função para extrair o nome do usuário do nome do arquivo
def extract_user_name(file_name):
    # Extrai o nome entre underscores (_nome_)
    parts = file_name.split('_')
    if len(parts) >= 2:  # Verifica se há pelo menos dois underscores
        return parts[-1].split('.')[0]  # Pega a última parte antes do .csv
    return None

# Número máximo de usuários que você quer processar
max_users = 100  # Altere este valor para o número desejado

defalt_users = [
    {
        "Bear_education_": ["Darrell", "Gavin", "Iris", "Clint"]},
    {
        "Wolf_education_": ['Miguel', 'Vivian']},
    {
        "Wolf_office_": ['Emanuel']},
    {
        "Swan_unknown_": ['Bette', 'Isaiah', 'Reyna']}]

# Lista para armazenar os arquivos e os nomes dos usuários
arquivos = []
users = []

for files in defalt_users:
    for chave, users_names in files.items():
        arquivos += [(dir + chave+user+'.csv',user) for user in users_names]
        users += users_names

# Processar os arquivos
for file_name in csv_files:
    if len(users) >= max_users:
        break
    user_name = extract_user_name(file_name)
    if user_name:
        if user_name not in users:
            users.append(user_name)
            arquivos.append((dir + file_name, user_name))

# Dicionário para armazenar os dados dos consumidores
consumidor = {}

# Processar cada arquivo
for arquivo, cosumidor_name in arquivos:
    c = pd.read_csv(arquivo, delimiter=",").iloc[:, 1:]
    c = c.set_axis(list(c.iloc[:, 0]), axis=0).iloc[:, 1:]

    # Converter o índice para o tipo de dados 'datetime'
    c.index = pd.to_datetime(c.index)

    # Criar uma série com intervalo de horas para o período desejado
    periodo_completo = pd.date_range(start="2016-01-01 00:00:00", end="2017-12-31 23:00:00", freq='h')

    # Reamostrar o DataFrame para o novo período completo e aplicar a interpolação linear
    consumidor[cosumidor_name] = c.reindex(periodo_completo).interpolate(method='linear')

    print((cosumidor_name, consumidor[cosumidor_name].mean().iloc[0]), end=" ")
# Out:
# ('Darrell', np.float64(39.28045494186047)) ('Gavin', np.float64(89.97713692145462)) ('Iris', np.float64(45.50607914956681)) ('Clint', np.float64(56.78198553921568)) ('Miguel', np.float64(35.105273811559506)) ('Vivian', np.float64(71.32430717054264)) ('Emanuel', np.float64(15.086507424190607)) ('Bette', np.float64(37.11234284893739)) ('Isaiah', np.float64(119.07638425043079)) ('Reyna', np.float64(87.3732023555096)) ('Perry', np.float64(52.779484694750046)) ('Jo', np.float64(1.1587610009119926)) ('Deandre', np.float64(28.96344163246694)) ('Herb', np.float64(12.941177325581396)) ('Charlie', np.float64(13.202559474885845)) ('Traci', np.float64(2.418940914272686)) ('Christi', np.float64(4.3386015304377565)) ('Leta', np.float64(17.021187870497034)) ('Miriam', np.float64(23.047986434108523)) ('Janie', np.float64(118.7833542122663)) ('Winford', np.float64(47.30465142791997)) ('Rosaria', np.float64(31.004504103967168)) ('Jerold', np.float64(327.68588172889145)) ('Simon', np.float64(19.46768125854993)) ('Josiah', np.float64(88.04359866621067)) ('Audrea', np.float64(286.843880124259)) ('Fred', np.float64(8.507106292749658)) ('Antonette', np.float64(31.80197365091307)) ('Kelvin', np.float64(284.62580935932516)) ('Lynda', np.float64(11.953954343365252)) ('Delores', np.float64(73.33231661821705)) ('Henrietta', np.float64(29.473443912448698)) ('Cordelia', np.float64(26.024423221614228)) ('Sherri', np.float64(57.86594746067031)) ('Grover', np.float64(17.741840800273597)) ('Sharron', np.float64(43.396961069311445)) ('Kris', np.float64(106.81249487004105)) ('Ora', np.float64(220.7604919630643)) ('Linnie', np.float64(195.1994527731859)) ('Burt', np.float64(2.054526111491108)) ('Reynaldo', np.float64(32.38505386763951)) ('Madge', np.float64(89.80351493388052)) ('Lelia', np.float64(3.5532245554035566)) ('Olga', np.float64(71.92968498917008)) ('Donald', np.float64(151.12790947902417)) ('Estela', np.float64(377.4181196933424)) ('Margaret', np.float64(3.2689539073187417)) ('Rodrigo', np.float64(34.45188843194254)) ('Omer', np.float64(336.79731643296856)) ('Terina', np.float64(83.17926300159598)) ('Marina', np.float64(40.44931595702235)) ('Ida', np.float64(26.255223723210214)) ('Franklin', np.float64(157.0795923535112)) ('Dalia', np.float64(186.25445251937987)) ('Nora', np.float64(151.0733869129047)) ('Kristen', np.float64(53.01561781683879)) ('Kathy', np.float64(5.152370041039672)) ('Shanna', np.float64(297.28836069311444)) ('Harley', np.float64(3.1955702861377113)) ('Camilla', np.float64(19.186550082649337)) ('Albert', np.float64(72.80885833903329)) ('Dan', np.float64(176.86416234395486)) ('Efrain', np.float64(48.356507509689926)) ('Alisha', np.float64(12.3501004704569)) ('Stefani', np.float64(10.50189116507068)) ('Rolland', np.float64(40.77350832193343)) ('Graham', np.float64(75.87842940633337)) ('Beatrice', np.float64(42.966987859097124)) ('Caroline', np.float64(149.38535653214774)) ('Joanna', np.float64(0.8252165925672595)) ('Donnell', np.float64(41.72733099635202)) ('Christoper', np.float64(29.62365244771317)) ('Nona', np.float64(97.97010288417692)) ('Enriqueta', np.float64(84.54273885113915)) ('Casey', np.float64(77.97892512824897)) ('Hugo', np.float64(79.93604286610044)) ('Dana', np.float64(97.66373489512084)) ('Beverly', np.float64(661.4488198928409)) ('Nancie', np.float64(62.27703140674875)) ('Brian', np.float64(105.50738144094848)) ('Leopoldo', np.float64(6.606620177838578)) ('Kristine', np.float64(24.00551499088007)) ('Lawrence', np.float64(7.269231446648426)) ('Earnest', np.float64(60.413867134062926)) ('Cecil', np.float64(62.28566546967623)) ('Richelle', np.float64(85.39316350319199)) ('Lincoln', np.float64(160.95513765389876)) ('Reina', np.float64(80.17377301487772)) ('Eleanor', np.float64(36.33175588805289)) ('Dania', np.float64(41.021746565581715)) ('Orville', np.float64(37.25508852029184)) ('Kendra', np.float64(469.5308670124836)) ('Corine', np.float64(0.2737601185725687)) ('Jana', np.float64(83.84318479242185)) ('Marty', np.float64( ...

# %%
consumidor[users[0]]
# Out:
#                      meter_reading
# 2016-01-01 00:00:00        21.0625
# 2016-01-01 01:00:00        20.4882
# 2016-01-01 02:00:00        20.3655
# 2016-01-01 03:00:00        20.2887
# 2016-01-01 04:00:00        19.9610
# ...                            ...
# 2017-12-31 19:00:00        17.6102
# 2017-12-31 20:00:00        17.6022
# 2017-12-31 21:00:00        17.5627
# 2017-12-31 22:00:00        17.6767
# 2017-12-31 23:00:00        17.8782
#
# [17544 rows x 1 columns]

# %%
def label_figure(users, title, ylabel, xlabel, fontsize, rotation):
    # plt.title(title,  fontsize = fontsize)
    plt.ylabel(ylabel,  fontsize = fontsize)
    plt.xlabel(xlabel,  fontsize = fontsize)
    plt.xticks(fontsize=fontsize-3, rotation=rotation)
    plt.yticks(fontsize=fontsize-3)
    
    if len(users) > 0:
        plt.legend(users, loc='lower center', bbox_to_anchor=(0.5, 1.0), ncol=5, fontsize=fontsize-3)
    
    plt.tight_layout()

# %%
#@title **Comsumo de 2016 à 2017**
font = 18
plt.figure(figsize=(11,5))
for user in users[:10]:
    plt.plot(consumidor[user].resample('ME').mean())

plt.ylabel('Consumo(kWh)',  fontsize = font)
plt.xlabel('Mês',  fontsize = font)
plt.xticks(fontsize=font-3)
plt.yticks(fontsize=font-3)

if len(users) > 0:
    plt.legend(users, loc='lower center', bbox_to_anchor=(0.5, 1.0), ncol=5, fontsize=font-4)

plt.tight_layout()

os.makedirs("./figuras/consumo", exist_ok=True)
plt.savefig(f"./figuras/consumo/{max_users}-consumo.eps", format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
#@title **Acesso aos Arquivos Meterologicos**
# https://mapas.inmet.gov.br/

Met = {}
anos = ['2016', '2017']
for ano in anos:
    arquivo = f"./smart-grid/dados/{ano}/INMET_SE_ES_A612_VITORIA_01-01-{ano}_A_31-12-{ano}.csv"
    Met[ano] = pd.read_csv(os.path.abspath(arquivo), delimiter=";")
    
DadosMet = pd.concat([Met[ano] for ano in anos])

colunas_selecionadas = ["Data","Hora (UTC)","Temp. Ins. (C)","Vel. Vento (m/s)","Radiacao (KJ/m²)", "Chuva (mm)"]
DadosMet = DadosMet[colunas_selecionadas]
DadosMet.columns=['Data','Hora','temperatura', 'vento', 'radiacao', 'chuva']

# Acerto Hora
try:
    DadosMet['Hora'] /= 100
    DadosMet['Hora'] = DadosMet['Hora'].astype(str).str.replace(".0", ":00")
    DadosMet['Data'] = pd.to_datetime(DadosMet['Data'] + ' ' + DadosMet['Hora'], format='%d/%m/%Y %H:%M')
except:
    DadosMet['Data'] = pd.to_datetime(DadosMet['Data'] + ' ' + DadosMet['Hora'])
# DadosMet = DadosMet.set_axis(list(DadosMet['Data']), axis=0)

# Definir a coluna 'Data' como índice
DadosMet = DadosMet.set_index('Data')

# Converter vírgulas para pontos e transformar em numérico
DadosMet['radiacao'] = pd.to_numeric(DadosMet['radiacao'].str.replace(",", "."), errors='coerce')
DadosMet['temperatura'] = pd.to_numeric(DadosMet['temperatura'].str.replace(",", "."), errors='coerce')
DadosMet['vento'] = pd.to_numeric(DadosMet['vento'].str.replace(",", "."), errors='coerce')
DadosMet['chuva'] = pd.to_numeric(DadosMet['chuva'].str.replace(",", "."), errors='coerce')

DadosMet['radiacao'] = DadosMet['radiacao'].fillna(0.0)

# Calcular irradiância solar (converter kJ/m² para W/m²)
DadosMet['irradiancia'] = round(DadosMet['radiacao'] * 0.2777777778, 1)

# Remover colunas desnecessárias
DadosMet = DadosMet.drop(columns=['Hora', 'radiacao'])

# Interpolar valores faltantes
DadosMet = DadosMet.interpolate(method='time').bfill()

# Garantir que o índice seja datetime
DadosMet.index = pd.to_datetime(DadosMet.index)

DadosMet
# Out:
#                      temperatura  vento  chuva  irradiancia
# Data
# 2016-01-01 00:00:00         26.9    3.0    0.0          0.0
# 2016-01-01 01:00:00         26.8    2.9    0.0          0.0
# 2016-01-01 02:00:00         26.7    2.2    0.0          0.0
# 2016-01-01 03:00:00         26.7    2.5    0.0          0.0
# 2016-01-01 04:00:00         26.4    1.4    0.0          0.0
# ...                          ...    ...    ...          ...
# 2017-12-31 19:00:00         30.5    3.9    0.0        507.6
# 2017-12-31 20:00:00         28.4    3.8    0.0        222.6
# 2017-12-31 21:00:00         27.6    3.4    0.0         72.5
# 2017-12-31 22:00:00         27.4    2.6    0.0          2.5
# 2017-12-31 23:00:00         27.5    1.7    0.0          0.0
#
# [17544 rows x 4 columns]

# %%
#@title **Gráfico irradiancia dia 1 do primeiro ano**
plt.figure(figsize=(10,4))

plt.grid(True)
plt.title(f'Irradiancia dia {anos[0]}-01-01',  fontsize = 10)
plt.ylabel('Irradiancia (wh/m²)',  fontsize = 10)
plt.xlabel('Horas',  fontsize = 10)

plt.plot(DadosMet['irradiancia'][:24], color='orange')
plt.show()

# %%
#@title **Gráfico Vento dia 1 do primeiro ano**
plt.figure(figsize=(10,4))

plt.grid(True)
plt.title(f'Velocidade do vento dia {anos[0]}-01-01',  fontsize = 10)
plt.ylabel('Velocidade (m/s)',  fontsize = 10)
plt.xlabel('Horas',  fontsize = 10)

plt.plot(DadosMet['vento'][:24], color='grey')
plt.show()

# %%
plt.figure(figsize=(10,4))

plt.grid(True)
plt.title(f'Temperatura dia {anos[0]}-01-01',  fontsize = 10)
plt.ylabel('Temperatura (°C)',  fontsize = 10)
plt.xlabel('Horas',  fontsize = 10)

plt.plot(DadosMet['temperatura'][:24], color='red')
plt.show()

# %%
#@title **Gráfico chuva mês 1 do primeiro ano**
plt.figure(figsize=(10,4))

plt.grid(True)
plt.title(f'Chuva - {anos[0]}-01',  fontsize = 10)
plt.ylabel('Chuva (mm)',  fontsize = 10)
plt.xlabel('Horas',  fontsize = 10)

plt.plot(DadosMet['chuva'][:24*30], color='blue')
plt.show()

# %%
#@title **Simulação de Sujidade com Modelo de Kimber**

from pvlib.soiling import kimber

# Parâmetros do modelo de Kimber para o clima de Vitória
# soiling_loss_rate: perda de eficiência diária (valor típico 0.15% ao dia) [7, 2]
# cleaning_threshold: quantidade de chuva (mm) para limpar o painel (valor típico 6 mm) [1, 2]
# grace_period: dias sem acúmulo de sujeira após a chuva (valor típico 14 dias) [1, 2]
# max_soiling: perda máxima de eficiência, caso o soiling acumulado seja muito alto (valor típico 30%) [1, 2]

soiling_loss_rate = 0.0020
cleaning_threshold = 25
grace_period = 14
max_soiling = 0.3

# A granularidade do modelo Kimber é diária (24h) [1], então a série de chuva precisa ser diária.
# No seu caso, como o `DadosMet` já está em granularidade horária,
# o `pvlib` já faz a agregação interna, mas vamos garantir que a série de chuva seja passada corretamente.
# A função `kimber` espera a chuva em uma série temporal.
# Certifique-se que sua coluna `chuva` está no formato numérico float.

# O modelo `pvlib.soiling.kimber` retorna o "soiling ratio", um fator entre 0 e 1 [3]
soiling_ratio_series = kimber(
    rainfall=DadosMet['chuva'], 
    cleaning_threshold=cleaning_threshold,
    soiling_loss_rate=soiling_loss_rate,
    grace_period=grace_period,
    max_soiling=max_soiling
)

soiling_ratio_series.name = 'soiling'

# Isso garante que a série soiling_ratio_series tenha exatamente o mesmo índice (datas e horários) que o DataFrame DadosMet.
# Se houver algum horário faltando em soiling_ratio_series, ele será adicionado como NaN e pode ser preenchido depois.
soiling_ratio_series = soiling_ratio_series.reindex(DadosMet.index)

# O `soiling_ratio_series` será uma série temporal com o mesmo índice que `DadosMet`, mas com valores diários
# que são aplicados a cada hora do dia. O `pvlib` lida com essa granularidade,
# mas para ter certeza que temos uma série de mesmo tamanho, faremos uma interpolação ffill
soiling_ratio_series = soiling_ratio_series.interpolate(method='time').ffill().bfill()

# %%
from datetime import datetime
plt.figure(figsize=(8,4))

# daily rain totals
daily_rain = DadosMet['chuva'].iloc[:]
plt.plot(daily_rain.index, daily_rain.values/25.4, color='blue')
plt.plot(soiling_ratio_series.index, soiling_ratio_series.values*100.0, color='maroon')
plt.hlines(
    cleaning_threshold/25.4, xmin=datetime(2016, 1, 1), xmax=datetime(2017, 12, 31),
    linestyles='--')

plt.grid()
plt.title(
    f'Modelo de Sujidade de Kimber, a linha tracejada mostra o limite ({cleaning_threshold}[mm])')
plt.xlabel('tempo')
plt.ylabel('Acúmulo de sujeira e precipitação diária')
plt.legend(['precipitação diária [polegadas]', 'sujeira [%]'])
plt.tight_layout()

plt.xlim(pd.Timestamp('2016-01-01 00:00:00'), pd.Timestamp('2017-12-31 23:00:00'))

plt.show()

# %%
#@title **Informações da placa**
# https://www.neosolar.com.br/loja/painel-solar-fotovoltaico-280w-osda-oda280-30-p.html

#POTENCIA GERADA PELOS PV's DO MODELO ODA280-30-P 280W
Vmppt = 31.94   # é a tensão no ponto de máxima potência (V);
Imppt = 8.77    # é a corrente no ponto de máxima potência (A).
Voc = 38.33     # é a tensão de circuito aberto do módulo (V);
Isc = 9.41      # é a corrente de curto circuito da célula (A);
nc = 0.1899     # é a eficiência da placa
Not = 45        # é a temperatura nominal de operação da célula (oC);
Kv = -0.3       # é o coeficiente de tensão/temperatura (V/ oC);
Ki = 0.06       # é o coeficiente de corrente/temperatura (A/ oC);

# Constantes
RNOCT = 1000
ta = 0.9

power_placa = Voc*Isc   # é a potencia da Placa

# %%
NPaineis = {}
ir_med = 4.5
horas_exposto = 4       # é a quantidade de horas de exposição da placa
for user in users:
    consumo_medio = (consumidor[user]*1000).mean().iloc[0] # media Wh
    NPaineis[user] =  math.ceil((consumo_medio/(power_placa*ir_med*0.75*horas_exposto)))
print(f"Placas - {NPaineis}")
# Out:
# Placas - {'Darrell': 9, 'Gavin': 19, 'Iris': 10, 'Clint': 12, 'Miguel': 8, 'Vivian': 15, 'Emanuel': 4, 'Bette': 8, 'Isaiah': 25, 'Reyna': 18, 'Perry': 11, 'Jo': 1, 'Deandre': 6, 'Herb': 3, 'Charlie': 3, 'Traci': 1, 'Christi': 1, 'Leta': 4, 'Miriam': 5, 'Janie': 25, 'Winford': 10, 'Rosaria': 7, 'Jerold': 68, 'Simon': 4, 'Josiah': 19, 'Audrea': 59, 'Fred': 2, 'Antonette': 7, 'Kelvin': 59, 'Lynda': 3, 'Delores': 16, 'Henrietta': 7, 'Cordelia': 6, 'Sherri': 12, 'Grover': 4, 'Sharron': 9, 'Kris': 22, 'Ora': 46, 'Linnie': 41, 'Burt': 1, 'Reynaldo': 7, 'Madge': 19, 'Lelia': 1, 'Olga': 15, 'Donald': 32, 'Estela': 78, 'Margaret': 1, 'Rodrigo': 8, 'Omer': 70, 'Terina': 18, 'Marina': 9, 'Ida': 6, 'Franklin': 33, 'Dalia': 39, 'Nora': 32, 'Kristen': 11, 'Kathy': 2, 'Shanna': 62, 'Harley': 1, 'Camilla': 4, 'Albert': 15, 'Dan': 37, 'Efrain': 10, 'Alisha': 3, 'Stefani': 3, 'Rolland': 9, 'Graham': 16, 'Beatrice': 9, 'Caroline': 31, 'Joanna': 1, 'Donnell': 9, 'Christoper': 7, 'Nona': 21, 'Enriqueta': 18, 'Casey': 17, 'Hugo': 17, 'Dana': 21, 'Beverly': 136, 'Nancie': 13, 'Brian': 22, 'Leopoldo': 2, 'Kristine': 5, 'Lawrence': 2, 'Earnest': 13, 'Cecil': 13, 'Richelle': 18, 'Lincoln': 34, 'Reina': 17, 'Eleanor': 8, 'Dania': 9, 'Orville': 8, 'Kendra': 97, 'Corine': 1, 'Jana': 18, 'Marty': 1, 'Buford': 1, 'Marie': 5, 'Myles': 11, 'Sana': 200, 'Bethel': 1}

# %%
#@title **Painel solar**
base_power = []
for idx, row in DadosMet.iterrows():
    r   = row['irradiancia']
    Ta  = row['temperatura']
    Vw  = row['vento']
    Tc  = Ta + ((r/RNOCT) * (9.5/(5.7+3.8*Vw)) * (Not-20) * (1 - (nc/ta)))
    I   = r * (Isc + Ki *(Tc-25))
    V   = Voc - Kv *(Tc-25)
    FF  = (Vmppt * Imppt)/(Voc * Isc)
    base_power.append((idx, FF * V * I / 10000))
    
def PowerPainel(users=users, DadosMet=DadosMet):
    PotPVM, PotPVMS = {}, {}
    for user in users:
        PotPVM[user], PotPVMS[user] = [], []
        for idx, power in base_power:
            power       *= NPaineis[user]
            power_suj   = power * (1 - soiling_ratio_series.loc[idx])
            
            PotPVM[user].append(power)
            PotPVMS[user].append(power_suj)
            
        PotPVM[user]  = pd.DataFrame(PotPVM[user], index=DadosMet.index, columns=["Power (kW)"])
        PotPVMS[user] = pd.DataFrame(PotPVMS[user], index=DadosMet.index, columns=["Power (kW)"])
    return PotPVM, PotPVMS

PotPVM, PotPVMS = PowerPainel()
PotPVM[users[0]].iloc[:24,:]
# Out:
#                      Power (kW)
# Data
# 2016-01-01 00:00:00    0.000000
# 2016-01-01 01:00:00    0.000000
# 2016-01-01 02:00:00    0.000000
# 2016-01-01 03:00:00    0.000000
# 2016-01-01 04:00:00    0.000000
# 2016-01-01 05:00:00    0.000000
# 2016-01-01 06:00:00    0.000000
# 2016-01-01 07:00:00    0.000000
# 2016-01-01 08:00:00    0.000000
# 2016-01-01 09:00:00   10.387999
# 2016-01-01 10:00:00   70.038800
# 2016-01-01 11:00:00  143.049889
# 2016-01-01 12:00:00  228.117985
# 2016-01-01 13:00:00  290.999328
# 2016-01-01 14:00:00  325.635531
# 2016-01-01 15:00:00  349.149068
# 2016-01-01 16:00:00  333.928037
# 2016-01-01 17:00:00  301.084223
# 2016-01-01 18:00:00  238.826520
# 2016-01-01 19:00:00  173.244867
# 2016-01-01 20:00:00  100.148169
# 2016-01-01 21:00:00   24.888647
# 2016-01-01 22:00:00    1.338499
# 2016-01-01 23:00:00    0.000000

# %%
PotPVM[user].iloc[:24,:].index.strftime('%HH')
# Out:
# Index(['00H', '01H', '02H', '03H', '04H', '05H', '06H', '07H', '08H', '09H',
#        '10H', '11H', '12H', '13H', '14H', '15H', '16H', '17H', '18H', '19H',
#        '20H', '21H', '22H', '23H'],
#       dtype='object', name='Data')

# %%
#@title **Geração no dia 1 do primeiro ano**
plt.figure(figsize=(8,4))

for user in users[:10]:
    plt.plot(PotPVM[user].iloc[:,:].index, PotPVM[user].values)

label_figure(users, 'Geração Painel solar', 'Potência (kW)', 'Horas', 16, 0)

plt.ylim(0, 65)
plt.xlim(pd.Timestamp('2016-06-22 00:00:00'), pd.Timestamp('2016-06-22 23:00:00'))

os.makedirs("./figuras/geracao", exist_ok=True)
plt.savefig(f"./figuras/geracao/{max_users}-geracao.eps", format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
#@title **Geração com sujidade**  
plt.figure(figsize=(8,4))

# Soma mensal direto para todos os usuários
pvm  = pd.concat([PotPVM[u]  for u in users], axis=1).resample("ME").sum().sum(axis=1)
pvms = pd.concat([PotPVMS[u] for u in users], axis=1).resample("ME").sum().sum(axis=1)

plt.plot(pvm.index, pvm.values, label="Geração sem sujidade")   # type: ignore
plt.plot(pvms.index, pvms.values, label="Geração com sujidade") # type: ignore

label_figure(['Geração sem sujidade', 'Geração com sujidade'], 'Geração Painel solar com sujidade', 'Potência (kW)', 'Meses', 16, 0)

os.makedirs("./figuras/geracao", exist_ok=True)
plt.savefig(f"./figuras/geracao/{max_users}-geracao-sujidade.eps", format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
total = sum([(PotPVM[user].sum() - PotPVMS[user].sum()).values[0] for user in users])
porcentagem = (total / sum([PotPVM[user].sum().values[0] for user in users])) * 100
print(f"Potencia perdida por sujidade: {total/1000:.2f} MW")
print(f"Porcentagem perdida por sujidade: {porcentagem:.2f}%")
# Out:
# Potencia perdida por sujidade: 8193.90 MW
# Porcentagem perdida por sujidade: 3.69%

# %%
#@title **EnergBaterry**
def energBaterry(l, g, max_battery):
  battery = 0
  bat   = l.copy()*0
  load  = l.copy()
  grid  = g.copy()
  
  
  for i, energ in enumerate(zip(load.iloc[:,0], grid.iloc[:,0])):
    geracao, consumo = energ
    if int(bat.iloc[i:i+1,:].index[0].strftime('%H')) == 1:
      battery = 0
    elif(i):
      battery    = bat.iloc[i-1,0]

    res   = geracao - consumo

    if(res < 0):
      consumo = (-1) * res
      res = 0
      consumo = consumo - battery
      if(consumo < 0):
        battery = (-1) * consumo
        consumo = 0
      else:
        battery = 0
    elif (battery < max_battery):
      consumo = 0
      if (res <= (max_battery-battery)):
        battery = battery + res
        res     = 0
      else:
        res     = res - (max_battery - battery)
        battery = max_battery
    else:
      consumo = 0

    grid.iloc[i,0]  = consumo
    load.iloc[i,0]  = res
    bat.iloc[i,0]   = battery
    
  df = round(pd.concat([grid, load, bat], axis=1), 1) # type: ignore
  df.columns = ['grid', 'load', 'battery']
  return df

# %%
print(f"geração len - {len(PotPVM[users[0]])}, consumo len - {len(consumidor[users[0]])}")
# Out:
# geração len - 17544, consumo len - 17544

# %%
# Bateria Megapack Tesla 1.9MW
# max_battery = 1900 # kW
# qtd_battery = 0

# consumidor_baterry = {}
# for chave, consumo in consumidor.items():
#     consumidor_baterry[chave] = energBaterry(PotPVM[chave], consumo, max_battery * qtd_battery)
# consumidor_baterry[users[0]].iloc[:24,:]

# %%
## Se valores ficarem None, datas diferentes entre geração e consumo
# sum([consumidor_baterry[user].isna().sum().sum() for user in users])

# %%
# for user in users[:10]: 
#     plt.figure(figsize=(8,4))
#     plt.grid(True)
#     plt.title(user+f'- Consumo {anos[0]} à {anos[1]}',  fontsize = 10)
#     plt.ylabel('kW',  fontsize = 10)
#     plt.xlabel('Mês',  fontsize = 10)

#     plt.plot(consumidor_baterry[user].resample('ME').sum().resample('ME').mean())
#     plt.legend(['Grid', 'Load', 'battery'])
#     plt.show()

# %%
#@title **Carga e descarga da bateria nos primeiros 4 mês de Janeiro de 2017 - Danna**
# plt.figure(figsize=(12,4))

# plt.grid(True)
# plt.title(f'Carga e descarga da bateria de {anos[0]} à {anos[1]} - '+users[0],  fontsize = 10)
# plt.ylabel('carga (kW)',  fontsize = 10)
# plt.xlabel('Data',  fontsize = 10)

# plt.plot(consumidor_baterry[users[0]]['battery'])#.iloc[:24*30*4,2:3])

# plt.show()

# %%
# consumo_ano = {}
# for user in users:
#     consumo_ano[user] = consumidor_baterry[user].resample('ME').sum()
#     # consumo_ano[user] = consumidor_baterry[user].copy()
# consumo_ano[users[0]]

# %%
# # Criar um dicionário vazio para armazenar os DataFrames de crédito
# credit = {user: pd.DataFrame(0.0, index=df.index, columns=['grid', 'load']) for user, df in consumo_ano.items()}

# # for user, df in consumo_ano.items():
# #     for index, row in df.iterrows():
# #         if row['load'] > row['grid']:
# #             credit[user].at[index, 'load'] = row['load'] - row['grid']
# #             credit[user].at[index, 'grid'] = 0
# #         else:
# #             credit[user].at[index, 'grid'] = row['grid'] - row['load']
# #             credit[user].at[index, 'load'] = 0

# # Exibir o DataFrame de crédito para o primeiro usuário

# # Remover   
# for user in users:
#     credit[user] = consumo_ano[user]#.iloc[:-3,:]
# display(credit[users[0]])

# %%
tarifa_unitaria = pd.DataFrame(index=pd.date_range(start='2016-01-31 00:00:00', end='2017-12-31 23:00:00', freq='1h'))
tarifa_unitaria = tarifa_unitaria.reindex(consumidor[users[0]].index)
tarifa_unitaria['tarifa_unitaria'] = 0.0

# SUBGRUPO A4 (TUSD + TE) Modalidade Verde 
tarifa_2015 = {'ponta': 0.68877 + 0.39493, 'fora ponta': 0.07451 + 0.24742} # RESOLUÇÃO HOMOLOGATÓRIA No 1.927, DE 4 DE AGOSTO DE 2015
tarifa_2016 = {'ponta': 0.51204 + 0.38631, 'fora ponta': 0.11703 + 0.24937} # RESOLUÇÃO HOMOLOGATÓRIA No 2.182, DE 29 DE NOVEMBRO DE 2016
tarifa_2017 = {'ponta': 1.24856 + 0.35173, 'fora ponta': 0.06780 + 0.22941} # RESOLUÇÃO HOMOLOGATÓRIA No 2.207, DE 14 DE MARÇO DE 2017

for idx in tarifa_unitaria.index:
    if idx.year == 2016:
        if idx.month < 11 or (idx.month == 11 and idx.day < 29):
            tarifa = tarifa_2015
        else:
            tarifa = tarifa_2016
    else:
        if idx.month < 3 or (idx.month == 3 and idx.day < 14):
            tarifa = tarifa_2016
        else:
            tarifa = tarifa_2017

    if 18 <= idx.hour <= 21:
        tarifa_unitaria.loc[idx, 'tarifa_unitaria'] = tarifa['ponta']
    else:
        tarifa_unitaria.loc[idx, 'tarifa_unitaria'] = tarifa['fora ponta']

display(tarifa_unitaria)
# Out:
#                      tarifa_unitaria
# 2016-01-01 00:00:00          0.32193
# 2016-01-01 01:00:00          0.32193
# 2016-01-01 02:00:00          0.32193
# 2016-01-01 03:00:00          0.32193
# 2016-01-01 04:00:00          0.32193
# ...                              ...
# 2017-12-31 19:00:00          1.60029
# 2017-12-31 20:00:00          1.60029
# 2017-12-31 21:00:00          1.60029
# 2017-12-31 22:00:00          0.29721
# 2017-12-31 23:00:00          0.29721
#
# [17544 rows x 1 columns]

# %%
#@title **Tarifa no ano de 2016**
plt.figure(figsize=(8,4))

plt.grid(True)
plt.title('Tarifa no ano de 2016',  fontsize = 10)
plt.ylabel('Tarifa(R$/kWh)',  fontsize = 10)
plt.xlabel('Mês',  fontsize = 10)

plt.plot(tarifa_unitaria.iloc[:168,:])

plt.show()

# %%
#@title **Tarifas nos anos de 2016 à 2017**
plt.figure(figsize=(8,4))

plt.grid(True)
plt.title('Tarifas nos anos de 2016 à 2017',  fontsize = 10)
plt.ylabel('Tarifa(R$/kWh)',  fontsize = 10)
plt.xlabel('Mês',  fontsize = 10)

plt.plot(tarifa_unitaria['tarifa_unitaria'].resample('ME').mean())

plt.show()

# %%
# Agrupamento
agrupamento     = lambda dados: pd.concat([df for df in dados.values()], axis=1).sum(axis=1).to_frame(name=dados[users[0]].columns[0])
consumidor_ALL  = agrupamento(consumidor)
consumidor_ALL
# Out:
#                      meter_reading
# 2016-01-01 00:00:00    4899.658700
# 2016-01-01 01:00:00    6199.359100
# 2016-01-01 02:00:00    6230.115100
# 2016-01-01 03:00:00    6211.832800
# 2016-01-01 04:00:00    6251.138767
# ...                            ...
# 2017-12-31 19:00:00    6639.842300
# 2017-12-31 20:00:00    6643.937500
# 2017-12-31 21:00:00    6640.163000
# 2017-12-31 22:00:00    6516.227600
# 2017-12-31 23:00:00    6425.657300
#
# [17544 rows x 1 columns]

# %%
#@title **Custo anual de eletricidade**
c_fit = 0
c_tarifa_unitaria = tarifa_unitaria.iloc[:,0]
Ce = lambda e_b, indicador=1: (energBaterry(agrupamento(PowerPainel()[indicador]), consumidor_ALL, e_b)['grid'] * c_tarifa_unitaria).sum()
print(
    round(Ce(572241, 0),2), round(Ce(572241),2))
# Out:
# 19798450.15 20129650.98

# %%
#@title **Custo anual relacionado à bateria**
SOH         = 0.8
rep         = 0.6 
# 3 baterias
capacidade  = 38.5 * 10**3 # capacidade de geração anual (kWh)
custo       = 9000000 # custo bateria em Dolar
dolar       = 3.1213 # cotação do dolar em 2025 
manutencao  = 50000 # custo de manutenção anual em Dolar
c_ic        = ((custo+manutencao) * dolar) / capacidade 
e_b         = 3.9 * 10**3 # capacidade da bateria

c_bat       = lambda e_b: (((1-SOH)/(1-rep))*c_ic*e_b)

round(c_bat(e_b)/10000,2)
# Out:
# 143.07

# %%
#@title **Custo anual total do sistema solar com bateria**
Cop = lambda e_b: c_bat(e_b) + Ce(e_b)
round(Cop(2000),2)
# Out:
# np.float64(34284124.74)

# %%
C_pv = lambda indicador=1: (energBaterry(agrupamento(PowerPainel()[indicador]), consumidor_ALL, 0)['grid'] * c_tarifa_unitaria).clip(lower=0).sum()
C_pv()
# Out:
# np.float64(35323091.550000995)

# %%
#@title **C_sav**
C_sav = lambda e_b: C_pv() - Cop(e_b)
round(C_sav(2000), 2)
# Out:
# np.float64(1038966.81)

# %%
#@title **Retorno de investimento**
roi = lambda e_b: (C_sav(e_b)/c_bat(e_b))*100
round(roi(348528.36539327),2)
# Out:
# np.float64(-88.12)

# %%
PotPVMS_cache = agrupamento(PowerPainel()[1])
def Ce_cached(e_b):
    return sum(energBaterry(PotPVMS_cache, consumidor_ALL, e_b)['grid'] * c_tarifa_unitaria.values)

# %%
def PowerPainel_optimizado(dates_limpeza):
    # Converte as datas de limpeza de string para datetime.date
    clean_dates = [datetime.strptime(d, '%Y-%m-%d').date() for d in dates_limpeza]
    
    soiling_ratio_series_optimized = kimber(
        rainfall=DadosMet['chuva'],
        cleaning_threshold=cleaning_threshold,
        soiling_loss_rate=soiling_loss_rate,
        grace_period=grace_period,
        max_soiling=max_soiling,
        manual_wash_dates=clean_dates
    )
    soiling_ratio_series_optimized = soiling_ratio_series_optimized.reindex(DadosMet.index)
    soiling_ratio_series_optimized = soiling_ratio_series_optimized.interpolate(method='time').ffill().bfill()
    
    PotPVMS_optimizado = {}
    for user in users:
        PotPVMS_optimizado[user] = []
        for idx, power in base_power:
            power *= NPaineis[user]
            power_suj_optimizado = power * (1 - soiling_ratio_series_optimized.loc[idx])
            PotPVMS_optimizado[user].append(power_suj_optimizado)
        PotPVMS_optimizado[user] = pd.DataFrame(PotPVMS_optimizado[user], index=DadosMet.index, columns=["Power (kW)"])
    return PotPVMS_optimizado

# %%
# Função de custo da limpeza
def cost_limpeza(num_cleanings):
    custo_por_painel = 20
    return custo_por_painel * sum(NPaineis[user] for user in users) * num_cleanings

# %%
# Nova função Ce para incluir o custo da limpeza
def Ce_limpeza(e_b, x):
    dates_limpeza_int = np.sort(np.unique(np.round(x).astype(int)))
    # Converte os dias em strings de data para o modelo de soiling
    dates_limpeza = [(pd.Timestamp('2016-01-01') + pd.Timedelta(days=int(d))).strftime('%Y-%m-%d') for d in dates_limpeza_int]
    PotPVMS_optimizado = PowerPainel_optimizado(dates_limpeza)
    return sum(energBaterry(agrupamento(PotPVMS_optimizado), consumidor_ALL, e_b)['grid'] * c_tarifa_unitaria.values)

# %%
from pymoo.util.ref_dirs import get_reference_directions
import threading

# Definir o problema de otimização
n_dates = 4
n_var = 1 + n_dates
objs = [
    lambda x: [c_bat(x[0])],
    lambda x: [Ce_limpeza(x[0], x[1:])],
    lambda x: [cost_limpeza(len(x[1:]))],
]

max_baterry = 38.5 * 10**3
max_days = (DadosMet.index[-1] - DadosMet.index[0]).days

xl = np.zeros(n_var)
xu = np.zeros(n_var)
xu[0] = max_baterry        # primeira variável = energia da bateria
xu[1:] = max_days          # próximas variáveis = dias de limpeza

problem = FunctionalProblem(n_var, objs, xl=xl, xu=xu)

# Configurar o algoritmo NSGA-III
pop_size = 100
ref_dirs_custom = get_reference_directions("das-dennis", 3, n_partitions=3)
algorithm = NSGA3(pop_size=pop_size, ref_dirs=ref_dirs_custom)

# # Função para realizar a otimização com base em uma seed específica
# def run_optimization(problem, algorithm, seed, verbose=False):
#     # Executar a otimização com a seed específica
#     result = minimize(problem, algorithm, seed=seed, termination=('n_gen', 50), verbose=verbose)

#     # Armazenar o resultado e a seed diretamente na lista
#     results_list.append((result, seed))

# # Lista de seeds que serão utilizadas para a otimização
# num_seeds = 5
# seeds = np.random.randint(1, 1000, size=num_seeds).tolist()

# # Criar uma lista para armazenar os resultados e as seeds
# results_list = []

# # Criar threads para executar a otimização para cada seed
# threads = [threading.Thread(target=run_optimization, args=(problem, algorithm, seed,)) for seed in seeds[:len(seeds)-1]]
# threads.append(threading.Thread(target=run_optimization, args=(problem, algorithm, seeds[len(seeds)-1], True,)))

# # Iniciar as threads
# for thread in threads:
#     thread.start()

# # Aguardar todas as threads serem concluídas
# for thread in threads:
#     thread.join()

# result_max = results_list[0]
# for result in results_list:
#     len_population = len(result[0].X)
#     if (len(result_max[0].X)<=len_population):
#         result = result

# # Acessar os resultados
# result = result_max[0]

result = minimize(problem, algorithm, seed=980, termination=('n_gen', 2), verbose=True)

final_population = result.X
final_objectives = result.F

from mpl_toolkits.mplot3d import Axes3D

# Imprimir os resultados
lista = []
for individual, objectives in zip(final_population, final_objectives):
    dist = np.linalg.norm([0, 0,0] - objectives)
    print("Individual: ", individual)
    print("Objectives: ", objectives)
    print("Distancia:  ", [dist])
    print("------------------------")

    lista.append((individual, objectives, dist))

print(min(lista, key=lambda x: x[2]))
Scatter().add(final_objectives).show()
scatter_plot = Scatter(title="Pareto Front")
# Out:
# ==========================================================
# n_gen  |  n_eval  | n_nds  |      eps      |   indicator
# ==========================================================
#      1 |      100 |      4 |             - |             -
#      2 |      200 |      4 |  0.0123413800 |         ideal
# Individual:  [9378.41353047  419.32070185  567.23677115  125.52472526  393.73367077]
# Objectives:  [ 3440509.36989089 27677411.330712     153360.        ]
# Distancia:   [np.float64(27890853.73349715)]
# ------------------------
# Individual:  [18475.12357642   563.96232703   348.86950111   317.5640975
#    112.81711066]
# Objectives:  [ 6777674.66406051 23684462.203446     153360.        ]
# Distancia:   [np.float64(24635627.513986934)]
# ------------------------
# Individual:  [38416.33316867   533.78147602   721.25575539   457.51138654
#    291.06813124]
# Objectives:  [14093188.98065376 20223719.520058     153360.        ]
# Distancia:   [np.float64(24650361.58274348)]
# ------------------------
# Individual:  [  2.05182521 106.99959714 477.64282284 275.59867219 564.29776852]
# Objectives:  [7.52720473e+02 3.52258638e+07 1.53360000e+05]
# Distancia:   [np.float64(35226197.60579845)]
# ------------------------
# (array([18475.12357642,   563.96232703,   348.86950111,   317.5640975 ,
#          112.81711066]), array([ 6777674.66406051, 23684462.203446  ,   153360.        ]), np.float64(24635627.513986934))

# %%
Scatter().add(final_objectives).show()

# %%
custo_por_painel        = 20  # Custo por painel em R$
custo_limpeza_sistema   = custo_por_painel * sum(NPaineis[user] for user in users) # Custo total de limpeza do sistema
custo_limpeza_sistema
# Out:
# 38340

# %%
# for result in results_list:
#     print(len(result[0].X), result)

# %%
# 49 [298]
# 52 (<pymoo.core.result.Result object at 0x000001D55FC04AD0>, 980)
# print(len(result.X))

# %%
# Criação do gráfico
plt.figure(figsize=(8, 6))

# Transposta do array final_objectives para facilitar o plotting
final_objectives_transpose = final_objectives.T

# Plotar cada objetivo
plt.plot(final_objectives_transpose[0], label="C_bat")
plt.plot(final_objectives_transpose[1], label="Ce")
plt.plot(final_objectives_transpose[2], label="Limpeza")

# Encontrar índice e ponto mínimo (individual, objectives, dist)
min_dist_index, min_dist_point = min(enumerate(lista), key=lambda x: x[1][2])

# Marcar o ponto mínimo para cada objetivo
plt.scatter(min_dist_index, min_dist_point[1][0], color='red', marker='o', label='C_bat (mínimo)')
plt.scatter(min_dist_index, min_dist_point[1][1], color='blue', marker='x', label='Ce (mínimo)')
plt.scatter(min_dist_index, min_dist_point[1][2], color='green', marker='^', label='Limpeza (mínimo)')

plt.xlabel("nds")
plt.ylabel("Valor dos Objetivos")
plt.legend()
plt.grid(True)
plt.title("Comparativo do custo em cada geração")
plt.show()

# %%
import matplotlib.pyplot as plt

# Rótulos dos objetivos
labels = ['C_bat', 'Ce', 'Limpeza']

# Criar o boxplot
plt.boxplot(final_objectives, labels=labels)

# Configurar o gráfico
plt.title('Boxplot dos Objetivos')
plt.xlabel('Objetivos')
plt.ylabel('Valores')
plt.grid(True)

# Exibir o gráfico
plt.show()
# Out:
# C:\Users\Arthur\AppData\Local\Temp\ipykernel_4468\4242839392.py:7: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(final_objectives, labels=labels)

# %%
from mpl_toolkits.mplot3d import Axes3D

# Função para verificar se um ponto é dominado por outro ponto
def is_dominated(point, other_points):
    return np.any(np.all(point >= other_points, axis=1))

# Encontrar o conjunto de Pareto
pareto_front = []
for i, point in enumerate(final_objectives):
    if not is_dominated(point, np.delete(final_objectives, i, axis=0)):
        pareto_front.append(point)

pareto_front = np.array(pareto_front)

# Encontrar índice e ponto mínimo (individual, objectives, dist)
min_dist_index, min_dist_point = min(enumerate(lista), key=lambda x: x[1][2])

# Criar gráfico 3D
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Plotar todos os pontos
ax.scatter(final_objectives[:, 0], final_objectives[:, 1], final_objectives[:, 2],
           label="Outros Pontos", alpha=0.6)

# Plotar ponto mínimo
ax.scatter(min_dist_point[1][0], min_dist_point[1][1], min_dist_point[1][2],
           color='red', s=80, label="Ponto Mínimo")

# Plotar frente de Pareto
ax.scatter(pareto_front[:, 0], pareto_front[:, 1], pareto_front[:, 2],
           color='green', s=60, label="Fronteira de Pareto")

# Rótulos
ax.set_xlabel("C_bat")
ax.set_ylabel("Ce")
ax.set_zlabel("Limpeza")

# Título
ax.set_title("Conjunto de Pareto (3 objetivos)")

# Legenda
ax.legend()
plt.show()

# %%
b = min(lista, key=lambda x: x[2])[0][0]
b
# Out:
# np.float64(18475.12357641957)

# %%
dias_limpeza = min(lista, key=lambda x: x[2])[0][1:]
datas_limpeza = [(pd.Timestamp('2016-01-01') + pd.Timedelta(days=int(d))).strftime('%Y-%m-%d') for d in dias_limpeza]
print("Dias de limpeza:", datas_limpeza)
# Out:
# Dias de limpeza: ['2017-07-17', '2016-12-14', '2016-11-13', '2016-04-22']

# %%
from datetime import datetime
from pvlib.soiling import kimber

plt.figure(figsize=(8,4))

# daily rain totals
daily_rain = DadosMet['chuva'].iloc[:]
plt.plot(daily_rain.index, daily_rain.values/25.4, color='blue')
plt.plot(soiling_ratio_series.index, soiling_ratio_series.values*100.0, color='maroon')
plt.hlines(
    cleaning_threshold/25.4, xmin=datetime(2016, 1, 1), xmax=datetime(2017, 12, 31),
    linestyles='--', color='gray', label='limite limpeza'
)

# Adiciona linhas verticais nas datas de limpeza
for d in datas_limpeza:
    plt.axvline(pd.to_datetime(d), color='green', linestyle=':', linewidth=1)
    plt.text(pd.to_datetime(d), plt.ylim()[1]*0.95, d, rotation=90, color='green', fontsize=8, va='top', ha='center')

plt.grid()
plt.title(
    f'Modelo de Sujidade de Kimber, a linha tracejada mostra o limite ({cleaning_threshold}[mm])')
plt.xlabel('tempo')
plt.ylabel('Acúmulo de sujeira e precipitação diária')
plt.legend(['precipitação diária [polegadas]', 'sujeira [%]', 'limite limpeza', 'datas limpeza'])
plt.tight_layout()
# Recalcula o soiling_ratio_series considerando as datas de limpeza

soiling_ratio_series_limpeza = kimber(
    rainfall=DadosMet['chuva'],
    cleaning_threshold=cleaning_threshold,
    soiling_loss_rate=soiling_loss_rate,
    grace_period=grace_period,
    max_soiling=max_soiling,
    manual_wash_dates=[pd.to_datetime(d).date() for d in datas_limpeza]
)
soiling_ratio_series_limpeza = soiling_ratio_series_limpeza.reindex(DadosMet.index).interpolate(method='time').ffill().bfill()

# Plota ao lado
plt.figure(figsize=(8,4))
plt.plot(daily_rain.index, daily_rain.values/25.4, color='blue')
plt.plot(soiling_ratio_series_limpeza.index, soiling_ratio_series_limpeza.values*100.0, color='maroon')
plt.hlines(
    cleaning_threshold/25.4, xmin=datetime(2016, 1, 1), xmax=datetime(2017, 12, 31),
    linestyles='--', color='gray', label='limite limpeza'
)
for d in datas_limpeza:
    plt.axvline(pd.to_datetime(d), color='green', linestyle=':', linewidth=1)
    plt.text(pd.to_datetime(d), plt.ylim()[1]*0.95, d, rotation=90, color='green', fontsize=8, va='top', ha='center')
plt.grid()
plt.title(
    f'Modelo de Sujidade de Kimber (com limpeza manual)')
plt.xlabel('tempo')
plt.ylabel('Acúmulo de sujeira e precipitação diária')
plt.legend(['precipitação diária [polegadas]', 'sujeira [%]', 'limite limpeza', 'datas limpeza'])
plt.tight_layout()
plt.xlim(pd.Timestamp('2016-01-01 00:00:00'), pd.Timestamp('2017-12-31 23:00:00'))
plt.show()

# %%
def Cop_limpeza(e_b, datas_limpeza):
    # Calcula o custo total considerando as datas de limpeza manual
    PotPVMS_optimizado = PowerPainel_optimizado(datas_limpeza)
    custo_bateria = c_bat(e_b)
    custo_energia = sum(energBaterry(agrupamento(PotPVMS_optimizado), consumidor_ALL, e_b)['grid'] * c_tarifa_unitaria.values)
    custo_limpeza = cost_limpeza(len(datas_limpeza))
    return custo_bateria + custo_energia + custo_limpeza

def C_pv_limpeza(datas_limpeza):
    # Considera limpeza também no C_pv (custo sem bateria, mas com limpeza)
    PotPVMS_optimizado = PowerPainel_optimizado(datas_limpeza)
    custo_pv = sum(energBaterry(agrupamento(PotPVMS_optimizado), consumidor_ALL, 0)['grid'] * c_tarifa_unitaria.values)
    custo_limpeza = cost_limpeza(len(datas_limpeza))
    return custo_pv + custo_limpeza

def C_sav_limpeza(e_b, datas_limpeza):
    return C_pv_limpeza(datas_limpeza) - Cop_limpeza(e_b, datas_limpeza)

def roi_limpeza(e_b, datas_limpeza):
    return (C_sav_limpeza(e_b, datas_limpeza) / c_bat(e_b)) * 100

roi_limpeza(b, datas_limpeza)
# Out:
# np.float64(71.33777257459577)

# %%
Cop_limpeza(b, datas_limpeza)
# Out:
# np.float64(30616492.580105513)

# %%
C_pv_limpeza(datas_limpeza)
# Out:
# 35451534.717799
